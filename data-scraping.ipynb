# %%
import requests
import time

import dotenv
import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize
from atproto import Client, client_utils

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
client = Client()
profile = client.login('stenjokesdev.bsky.social', 'bqauZEkLXFLpc35')
client.send_post(text='Hello World!')
# Out:
# CreateRecordResponse(uri='at://did:plc:szrtrv7hlmuzv5hg6e33t4dr/app.bsky.feed.post/3mq6hleewnw2b', cid='bafyreigogm3lsbg2d3mxuvcpwbosynel34v7e6pv54f5mxacuwoelv2nhi')

# %%
cursor = None
target_samples = 10000
collected_sentences = []

while len(collected_sentences) < target_samples:
  try:
    response = client.app.bsky.feed.search_posts_v2({
      'query': 'telecaster',
      'cursor': cursor
    })
    
    for 
  except Exception as err:
    raise err

# %%
UG_SEARCH_QUERY_PARAMS = 'SearchForm%5Bsearch_keyword%5D=telecaster&search_type=forum'
UG_PER_PAGE_PARAM = 'per-page=40'
UG_BASE_URL = f'https://www.ultimate-guitar.com/forum/search/search?{UG_SEARCH_QUERY_PARAMS}&{UG_PER_PAGE_PARAM}'

# %%
def is_valid(text: str):
  text_length = len(text)
  satisfied_length = text_length > 5 and text_length < 40
  
  return satisfied_length

# %%
sentences = []

for text in all_links:
  tokenized_texts = sent_tokenize(text)
  sentences.extend([t for t in tokenized_texts if is_valid(t)])

# %%
text_df = pd.DataFrame({
  'texts': sentences,
  'sentiments': ['Undetermined'] * len(sentences)
})
text_df.to_csv('./scraping-results.csv')
